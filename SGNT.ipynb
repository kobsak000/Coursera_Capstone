# %% [markdown]
# # THIS IS WEEK3 OF CHAPTER8 Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# # 1. Geting data.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %% [markdown]
# GET TABLE FROM WIKI

# %%
url = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")
soup = BeautifulSoup(url.content, "html.parser")
data = soup.find("table",{"class":"wikitable sortable"})
table_rows = data.find_all('tr')

# %% [markdown]
# CONVERT TABLE TO DATAFRAME

# %%
#Table to df
l=[]
for tr in table_rows:
    td = tr.find_all('td')
    row = [tr.text for tr in td]
    l.append(row)

# %% [markdown]
# CLEANING DATA

# %%
df = pd.DataFrame(l, columns=["Postcode", "Borough","Neighborhood"])
df = df[df.Borough !='Not assigned']
df = df.replace(to_replace='None', value=np.nan).dropna()
df['Neighborhood'] = df['Neighborhood'].str.replace("\n","")
df['Neighborhood'] = np.where(df['Neighborhood'] == 'Not assigned', df['Borough'],df['Neighborhood'])
df=df.groupby(['Postcode','Borough'])['Neighborhood'].apply(lambda x: ','.join(x)).reset_index()
df
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# ...

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# # 2. Get the latitude and the longitude coordinates of each neighborhood.

# %%
data = pd.read_csv("Geo.csv") 
df[['Latitude','Longitude']] = data[['Latitude','Longitude']]
df
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# ...

# %% [markdown]
# # 3. Clustering

# %% [markdown]
# ## Github can't execute folium so you can go here
# https://nbviewer.jupyter.org/github/kobsak000/Coursera_Capstone/blob/master/SGNT.ipynb

# %%
import folium

print('Folium installed and imported!')
# Out:
# Folium installed and imported!

# %%
latitude = 43.806
longitude = -79.194

# %%
neighborhood_map = folium.Map(location=[latitude, longitude], zoom_start=12)
neighborhood_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
incidents = folium.map.FeatureGroup()

for lat, lng, in zip(data.Latitude, data.Longitude):
    incidents.add_child(
        folium.features.CircleMarker(
            [lat, lng],
            radius=5, 
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# add incidents to map
neighborhood_map.add_child(incidents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
